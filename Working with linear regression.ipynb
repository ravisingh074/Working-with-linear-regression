# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel(r"C:\Users\HP\Downloads\home_price.xlsx")

# %%
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# 5  4200  750000

# %%
df.Area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# 5    4200
# Name: Area, dtype: int64

# %%
plt.xlabel("Area")
plt.ylabel("price")
plt.scatter(df.Area,df.Price, color = 'b', marker = '*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
 reg.predict([[3300]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628612.09964413])

# %%
reg.coef_
# Out:
# array([135.40925267])

# %%
reg.intercept_
# Out:
# 181761.56583629886

# %%
# y = m*x+c
135.40925267*3300+181761.56583629886
# Out:
# 628612.0996472989

# %%
d = pd.read_excel(r"C:\Users\HP\Downloads\pred_price.xlsx")

# %%
d
# Out:
#    Area
# 0  1000
# 1  1500
# 2  2300
# 3  3500
# 4  4000
# 5  4200
# 6  4500

# %%
p = reg.predict(d)

# %%
p
# Out:
# array([317170.81850534, 384875.44483986, 493202.84697509, 655693.95017794,
#        723398.57651246, 750480.42704626, 791103.20284698])

# %%
d['Price'] = p

# %%
d
# Out:
#    Area          Price
# 0  1000  317170.818505
# 1  1500  384875.444840
# 2  2300  493202.846975
# 3  3500  655693.950178
# 4  4000  723398.576512
# 5  4200  750480.427046
# 6  4500  791103.202847

# %%
d.to_excel('prediction.xlsx' )
